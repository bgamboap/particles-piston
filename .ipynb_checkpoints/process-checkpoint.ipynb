# %%
import matplotlib.pyplot as plt
import numpy as np
import subprocess

# %%
def run(NL, NR, NIter, gamma, TL, TR, log, NMed):
    
    command = "src/piston {0} {1} {2} {3} {4} {5} {6}".format(NL, NR, NIter, gamma, TL, TR, NMed)
    if(log == True):
        command = "src/pistonlog {0} {1} {2} {3} {4} {5} {6}".format(NL, NR, NIter, gamma,TL, TR, NMed)
        
    p = subprocess.Popen(command, shell=True, stdout=subprocess.PIPE, stderr=subprocess.STDOUT)
    a = p.stdout.readlines()
    for i in a:
        print(i.decode('utf-8'), end="")
    observable = [np.loadtxt("observables{0}.dat".format(i)) for i in range(NMed)] 
    
    logdata = np.array([])
    if(log == True):
        logdata = np.loadtxt("log.dat")
    return a, observable, logdata

# %%
NL = 100
NR = 100
N = NL + NR
NIter = 10000
gamma = 0.3
TR = 0.1
TL = 0.1
NMED = 20

output, obs, logdata = run(NL, NR, NIter, gamma, TL, TR, False, NMED)
smallest_t = min([i[-1,0] for i in obs])
dt = smallest_t/NIter
# Out:
# Program parameters:
# NL:      100
# NR:      100
# NIter:   10000
# gamma:   0.3
# TL:      0.1
# TR:      0.1
# Nmedias: 20

# %%
print(smallest_t,dt)
for i in range(NMED):
    ts = obs[i][:,0]
    xs = obs[i][:,1]
    plt.plot(ts, xs)
plt.show()
# Out:
# 50.2837964 0.00502837964

# %%
print(max)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-270b5e0f0ecf> in <module>
# ----> 1 ts = obs[:,0]
#       2 xm = obs[:,1]
#
# TypeError: list indices must be integers or slices, not tuple

# %%
NA = 100
EL = np.zeros((NIter,NA))
for i in range(NA):
    output, obs, logdata = run(NL, NR, NIter, gamma, True)
    EL[:,i] = obs[:,1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-104-67b421f10daf> in <module>
#       2 EL = np.zeros((NIter,NA))
#       3 for i in range(NA):
# ----> 4     output, obs, logdata = run(NL, NR, NIter, gamma, True)
#       5     EL[:,i] = obs[:,1]
#
# TypeError: run() missing 2 required positional arguments: 'TR' and 'log'

# %%
soma = EL[:,0] * 0
for i in range(NA):
    soma += EL[:,i]
soma /= NA

# %%
plt.plot(soma)
plt.plot(EL[:,0])

# %%
plt.plot(obs[:,2])
plt.plot(obs[:,3])

# %%
NL = 20
NR = 20
N = NL + NR
NIter = 200
gamma = 0.01
TR = 0.1
TL = 0.1

output, obs, logdata = run(NL, NR, NIter, gamma, TL, TR, True)
ts = obs[:,0]
xm = obs[:,1]


# Only run this cell if logdata exists
# If logdata exists, it will have every position of every particle
# %matplotlib inline
positions = np.zeros([NIter, N])
for i in range(N):
    positions[:,i] = logdata[:,3 + i*5]
    
fig, axs = plt.subplots(1,1)
for i in range(N):
    axs.plot(ts,positions[:,i])
#     axs.plot(positions[:,i],'o-')
    
axs.plot(ts,logdata[:,1], 'k--', linewidth=3)
# axs.plot(logdata[:,1], 'ko--', linewidth=3)
axs.set_ylim(-0.1, 1.1)
# axs.set_xlim(0.325, 0.37)
# axs.set_xlim(80, 90)
# Out:
# Program parameters:
# NL: 20
# NR: 20
# NIter: 200
# gamma: 0.01
# TL: 0.1
# TR: 0.1
# (-0.1, 1.1)

# %%
g = 10
NT = 100
TMAX = 0.3
times = np.linspace(0,TMAX, NT)
xRt = xR[t0] + vR[t0]*times
xLt = xL[t0] + vL[t0]*times
xmt = xm[t0] + vm[t0]*times - 0.5*g*times*times

plt.plot(times, xLt)
plt.plot(times, xRt)
plt.plot(times, xmt)
